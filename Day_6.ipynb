# %% [markdown]
# # Zerobase EDA 6일차
# ## Naver API 사용하기

# %% [markdown]
# ### 한글 깨짐 방지

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
plt.title('데이터 사이언스')
# Out:
# Text(0.5, 1.0, '데이터 사이언스')

# %% [markdown]
# ## 네이버 API 사용 등록

# %% [markdown]
# - 네이버 개발자 센터 - https://developers.naver.com/main/
# - Application
#     - 어플리케이션 등록
#     - 어플리케이션 이름 - Zerobase_data_school
#     - 사용 API
#         - 검색
#         - 데이터랩(검색어트렌드)
#         - 데이터랩(쇼핑인사이트)
#     - 환경추가
#         - WEB 설정
#         - http://localhost
#     - Clienct ID: ""
#     - Clienct Secret: ""

# %% [markdown]
# ## 네이버 검색 API 사용
#
# * https://developers.naver.com/docs/serviceapi/search/blog/blog.md#%EB%B8%94%EB%A1%9C%EA%B7%B8 - 개발 가이드

# %% [markdown]
# - urllib: http 프로토콜에 따라서 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request: 클라이언트의 요청을 처리하는 모듈
# - urllib.parse: url 주소에 대한 분석

# %%
# 네이버 검색 API 예제 - 블로그 검색(blog)
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 19:43:45 +0900",
# 	"total":222685,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>딥러닝<\/b>CCTV, 스마트 주차정산기--'코리아빌드'건축신기술 보다",
# 			"link":"https:\/\/blog.naver.com\/leenameun00\/223361857279",
# 			"description":"부스벽면에서는 <b>딥러닝<\/b>사물인식시스템(IDLE)에 대한 소개 영상이 나왔다. 최한슬 아이디스 과장은... 1.<b>딥러닝<\/b>CCTV : 아이디스 이세상에 단 하나밖에 없는 보안을 위한 인공지능, 아이디스 <b>딥러닝<\/b> 엔진을 통해... ",
# 			"bloggername":"일호이앤지 [치공구,간이자동화,로봇자동화,LCIA]",
# 			"bloggerlink":"blog.naver.com\/leenameun00",
# 			"postdate":"20240223"
# 		},
# 		{
# 			"title":"RTX4090 2Way 가능한 <b>딥러닝<\/b> 컴퓨터",
# 			"link":"https:\/\/blog.naver.com\/all_in_box\/223253916068",
# 			"description":"바로 러닝에 투입할 수 있는 최상의 상태로 출고 드리고 있습니다^^ 여기까지, <b>딥러닝<\/b> 컴퓨터로 맥시멈 2Way 증설이 가능토록 업그레이드를 염두한 가성비 높은 시스템을 소개 드렸습니다. 아시겠지만... ",
# 			"bloggername":"원트컴",
# 			"bloggerlink":"blog.naver.com\/all_in_box",
# 			"postdate":"20231102"
# 		},
# 		{
# 			"title":"개인 <b>딥러닝<\/b> 인공지능 머신 연습용 조립컴퓨터 고사양 조립PC",
# ...

# %%
response, response.getcode(), response.code, response.status
# Out:
# (<http.client.HTTPResponse at 0x21c79a8f5e0>, 200, 200, 200)

# %%
# 글자로 읽을 경우 decode utf-8 설정
print(response_body.decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 19:39:20 +0900",
# 	"total":222688,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>딥러닝<\/b>CCTV, 스마트 주차정산기--'코리아빌드'건축신기술 보다",
# 			"link":"https:\/\/blog.naver.com\/leenameun00\/223361857279",
# 			"description":"부스벽면에서는 <b>딥러닝<\/b>사물인식시스템(IDLE)에 대한 소개 영상이 나왔다. 최한슬 아이디스 과장은... 1.<b>딥러닝<\/b>CCTV : 아이디스 이세상에 단 하나밖에 없는 보안을 위한 인공지능, 아이디스 <b>딥러닝<\/b> 엔진을 통해... ",
# 			"bloggername":"일호이앤지 [치공구,간이자동화,로봇자동화,LCIA]",
# 			"bloggerlink":"blog.naver.com\/leenameun00",
# 			"postdate":"20240223"
# 		},
# 		{
# 			"title":"RTX4090 2Way 가능한 <b>딥러닝<\/b> 컴퓨터",
# 			"link":"https:\/\/blog.naver.com\/all_in_box\/223253916068",
# 			"description":"바로 러닝에 투입할 수 있는 최상의 상태로 출고 드리고 있습니다^^ 여기까지, <b>딥러닝<\/b> 컴퓨터로 맥시멈 2Way 증설이 가능토록 업그레이드를 염두한 가성비 높은 시스템을 소개 드렸습니다. 아시겠지만... ",
# 			"bloggername":"원트컴",
# 			"bloggerlink":"blog.naver.com\/all_in_box",
# 			"postdate":"20231102"
# 		},
# 		{
# 			"title":"개인 <b>딥러닝<\/b> 인공지능 머신 연습용 조립컴퓨터 고사양 조립PC",
# ...

# %%
# 네이버 검색 API 예제 - 책 검색(book)
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 19:43:49 +0900",
# 	"total":291,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"컴퓨터 비전과 딥러닝",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/36975852621",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3697585\/36975852621.20230906071248.jpg",
# 			"author":"오일석",
# 			"discount":"37050",
# 			"publisher":"한빛아카데미",
# 			"pubdate":"20230105",
# 			"isbn":"9791156645481",
# 			"description":"OpenCV와 텐서플로를 활용한 85개 파이썬 프로그램으로 배우는 컴퓨터 비전\n\n① 이론과 실습으로 균형 있게 배우는 컴퓨터 비전\n고전 방법과 딥러닝 방법으로 컴퓨터 비전 이론을 배우고 85개 파이썬 프로그램 실습으로 구현 방법을 직접 확인할 수 있습니다.\n\n② 딥러닝 중심의 컴퓨터 비전 교재\n딥러닝 중심으로 컴퓨터 비전을 소개하지만 영상 처리, 고전 컴퓨터 비전까지 모두 다루므로 컴퓨터 비전을 제대로 공부할 수 있습니다.\n\n③ [온라인 부록]으로 기초 지식 다지기\n파이썬 기본, 선형대수와 확률 이론 기초를 온라인 부록으로 제공하여 컴퓨터 비전을 공부하는 데 필요한 기초 지식을 빠르게 습득할 수 있습니다.\n\n* 본 도서는 대학 강의용 교재로 개발되었으므로 연습문제 해답은 제공하지 않습니다."
# 		},
# 		{
# 			"title":"딥러닝 EXPRESS",
# ...

# %%
# 네이버 검색 API 예제 - 영화 검색 -> API 지원 종료가 되어서 에러가 뜸...
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[18], line 13
#      11 request.add_header("X-Naver-Client-Id",client_id)
#      12 request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 13 response = urllib.request.urlopen(request)
#      14 rescode = response.getcode()
#      15 if(rescode==200):
#
# File c:\Program Files\Python310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Program Files\Python310\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# ...

# %%
# 네이버 검색 API 예제 - 카페 검색(cafearticle)
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 19:46:01 +0900",
# 	"total":60388,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>딥러닝<\/b> 기반의 SR모델의 정확성. jpg",
# 			"link":"http:\/\/cafe.naver.com\/opencv\/59045",
# 			"description":"Deep SR <b>딥러닝<\/b> 기반의 SR(수퍼 레졸류션) 모델이 요즘 대세죠. 하지만 제조업 AOI등에서 서브픽셀 기반의 정밀한 측정을 할때 과연 <b>딥러닝<\/b>기반의 SR 모델로 2배나 4배 크기로생성한 초해상도 이미지를 신뢰할수... ",
# 			"cafename":"OpenCV KOREA 대한민국 최고의 컴퓨터...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/opencv"
# 		},
# 		{
# 			"title":"노트북으로 <b>딥러닝<\/b> 하려면 어느정도 되야되나요?",
# 			"link":"http:\/\/cafe.naver.com\/develoid\/1022046",
# 			"description":"질문 대상 기기 ▶ 노트북 질문 키워드 ▶ 질문 내용 ▼ 아는 선생님께서 노트북으로 <b>딥러닝<\/b>을... 글카가 iris랑 arc중에 arc가 좋던데, arc로도 <b>딥러닝<\/b>이 가능할까요? 3. cpu중에 울트라 시리즈는 npu가 있어서... ",
# 			"cafename":"디벨로이드 [ IT 테크 커뮤니티 ]",
# 			"cafeurl":"https:\/\/cafe.naver.com\/develoid"
# 		},
# 		{
# 			"title":"<b>딥러닝<\/b> 논문 읽기 (자연어처리)",
# 			"link":"http:\/\/cafe.naver.com\/daehakwon\/139746",
# ...

# %%
# 네이버 검색 API 예제 - 쇼핑 검색(shop)
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 19:48:29 +0900",
# 	"total":15407,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"HP Z4G4 W-2223 워크스테이션 <b>딥러닝<\/b> 서버",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40230131328",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4023013\/40230131328.jpg",
# 			"lprice":"2424580",
# 			"hprice":"",
# 			"mallName":"11번가",
# 			"productId":"40230131328",
# 			"productType":"2",
# 			"brand":"HP",
# 			"maker":"",
# 			"category1":"디지털\/가전",
# 			"category2":"PC",
# 			"category3":"서버\/워크스테이션",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>딥러닝<\/b> AI 2GPU 워크스테이션 W5-3435X\/RTX A6000",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=45899552952",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4589955\/45899552952.jpg",
# 			"lprice":"23485000",
# 			"hprice":"",
# 			"mallName":"G마켓",
# 			"productId":"45899552952",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# ...

# %%
# 네이버 검색 API 예제 - 백과사전 검색(encyc)
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 19:48:41 +0900",
# 	"total":195,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>딥러닝<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3484358&cid=43667&categoryId=43667",
# 			"description":" 컴퓨터가 스스로 외부 데이터를 조합, 분석하여 학습하는 기술을 뜻한다. <b>딥러닝<\/b>의 고안으로 인공지능이 획기적으로 도약하게 되었다.  | 외국어 표기 | deep learning(영어) | 출처: 게티이미지 코리아... ",
# 			"thumbnail":"https:\/\/dthumb-phinf.pstatic.net\/?src=%22https%3A%2F%2Fpost-phinf.pstatic.net%2FMjAxODA3MTdfMjkx%2FMDAxNTMxNzg5NTgxMjI0.XBJDuZwrGE5ziXRFDlwmhaMQmv-R0hN2rEOGRhT1diAg.rfaHTZ9md172V1o13downTbWs9bklzh5E8VZYWMawj0g.JPEG%2FIEG60Bf2KQuKblYNhgMIPVLzBH5U.jpg%3Ftype%3Dm4500_4500_fst%22&type=w540#540x381#c381"
# 		},
# 		{
# 			"title":"<b>딥러닝<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3578519&cid=59088&categoryId=59096",
# 			"description":"영화는 이 운영체제를 이렇게 소개한다. “단순한 운영체제가 아닙니다. 또 하나의 의식입니다.” 최근 미국 실리콘밸리를 중심으로 한 기술 기업이 ‘<b>딥러닝<\/b>(Deep",
# ...

# %% [markdown]
# ## 상품 검색 실습 예제 - 딥러닝 검색

# %%
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("딥러닝")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 20:02:58 +0900",
# 	"total":15406,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"HP Z4G4 W-2223 워크스테이션 <b>딥러닝<\/b> 서버",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40230131328",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4023013\/40230131328.jpg",
# 			"lprice":"2424580",
# 			"hprice":"",
# 			"mallName":"11번가",
# 			"productId":"40230131328",
# 			"productType":"2",
# 			"brand":"HP",
# 			"maker":"",
# 			"category1":"디지털\/가전",
# 			"category2":"PC",
# 			"category3":"서버\/워크스테이션",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>딥러닝<\/b> AI 2GPU 워크스테이션 W5-3435X\/RTX A6000",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=45899552952",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4589955\/45899552952.jpg",
# 			"lprice":"23485000",
# 			"hprice":"",
# 			"mallName":"G마켓",
# 			"productId":"45899552952",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# ...

# %%
from PIL import Image
Image.open("sequence.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\PIL\JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\PIL\Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\PIL\Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#
# ...

# %% [markdown]
# ### 위 이미지에 나와 있는 시퀀스대로 실습 진행 예정

# %% [markdown]
# ## 1. gen_search_url()
# * 먼저 검색해야할 URL 만들기
# * 앞선 내용으로 검색할 URL과 그 URL에는 많은 옵션이 있는데 해당 옵션을 사용해서 URL을 만들어야 함

# %%
from PIL import Image
Image.open("gen_search_url.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\PIL\JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\PIL\Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\PIL\Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#
# ...

# %% [markdown]
# * 위 요청 변수들을 URL에 포함시켜야 함

# %% [markdown]
# encText = urllib.parse.quote("딥러닝") <br>
# url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
#
# * 이 코드를 함수화시켜준 것

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

# %%
gen_search_url("shop", "TEST", 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %% [markdown]
# ## 2. get_result_onepage()
# Get data on one page

# %%
import json 
import datetime 

def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    print("[%s] Url Request Success" % datetime.datetime.now())
    return json.loads(response.read().decode("utf-8"))

# %%
url = gen_search_url("shop", "딥러닝", 1, 5)
one_result = get_result_onpage(url)
# Out:
# [2024-03-13 20:13:58.175043] Url Request Success

# %%
one_result
# Out:
# {'lastBuildDate': 'Wed, 13 Mar 2024 20:13:58 +0900',
#  'total': 15409,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': 'HP Z4G4 W-2223 워크스테이션 <b>딥러닝</b> 서버',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=40230131328',
#    'image': 'https://shopping-phinf.pstatic.net/main_4023013/40230131328.jpg',
#    'lprice': '2424580',
#    'hprice': '',
#    'mallName': '11번가',
#    'productId': '40230131328',
#    'productType': '2',
#    'brand': 'HP',
#    'maker': '',
#    'category1': '디지털/가전',
#    'category2': 'PC',
#    'category3': '서버/워크스테이션',
#    'category4': ''},
#   {'title': '<b>딥러닝</b> AI 2GPU 워크스테이션 W5-3435X/RTX A6000',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=45899552952',
#    'image': 'https://shopping-phinf.pstatic.net/main_4589955/45899552952.jpg',
#    'lprice': '23485000',
#    'hprice': '',
#    'mallName': 'G마켓',
#    'productId': '45899552952',
#    'productType': '2',
#    'brand': '',
#    'maker': '',
# ...

# %% [markdown]
# ## 3. get_fields() -> convert pandas data frame
# one_result의 items 항목 안에서의 검색 결과를 데이터 프레임에 적재

# %%
import pandas as pd 

def get_fields(json_data):
    title = [each["title"] for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mall_name = [each["mallName"] for each in json_data["items"]]
    
    result_pd = pd.DataFrame({
        "title": title, 
        "link": link, 
        "lprice": lprice, 
        "mall": mall_name,   
    }, columns=["title", "lprice", "link", "mall"])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                             title    lprice  \
# 0             HP Z4G4 W-2223 워크스테이션 <b>딥러닝</b> 서버   2424580
# 1    <b>딥러닝</b> AI 2GPU 워크스테이션 W5-3435X/RTX A6000  23485000
# 2  [2GPU] <b>딥러닝</b> 서버 NF5280M6 G5315Y RTX A6000  22560000
# 3                   인공 지능 소형 서버 <b>딥 러닝</b> AI 지원   3064460
# 4      HP 에이치피 ai<b>딥러닝</b> 전문가 정보처리용 WORKSTATION   2424580
#
#                                                 link  mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  11번가
# 1  https://search.shopping.naver.com/gate.nhn?id=...   G마켓
# 2  https://search.shopping.naver.com/gate.nhn?id=...  11번가
# 3  https://search.shopping.naver.com/gate.nhn?id=...   G마켓
# 4  https://search.shopping.naver.com/gate.nhn?id=...  11번가

# %% [markdown]
# 하지만 title 데이터에 b태그가 포함되어있다... -> 제거해야함

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
def get_fields(json_data):
    title = [delete_tag(each["title"]) for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mall_name = [each["mallName"] for each in json_data["items"]]
    
    result_pd = pd.DataFrame({
        "title": title, 
        "link": link, 
        "lprice": lprice, 
        "mall": mall_name,   
    }, columns=["title", "lprice", "link", "mall"])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                      title    lprice  \
# 0             HP Z4G4 W-2223 워크스테이션 딥러닝 서버   2424580
# 1    딥러닝 AI 2GPU 워크스테이션 W5-3435X/RTX A6000  23485000
# 2  [2GPU] 딥러닝 서버 NF5280M6 G5315Y RTX A6000  22560000
# 3                   인공 지능 소형 서버 딥 러닝 AI 지원   3064460
# 4      HP 에이치피 ai딥러닝 전문가 정보처리용 WORKSTATION   2424580
#
#                                                 link  mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  11번가
# 1  https://search.shopping.naver.com/gate.nhn?id=...   G마켓
# 2  https://search.shopping.naver.com/gate.nhn?id=...  11번가
# 3  https://search.shopping.naver.com/gate.nhn?id=...   G마켓
# 4  https://search.shopping.naver.com/gate.nhn?id=...  11번가

# %% [markdown]
# ## 4. actMain() -> all data gathering
# 모든 데이터 모으기

# %%
# 딥러닝이라는 쇼핑몰에 대한 검색 결과를 1000개를 데이터 프레임에 적재
result_mol = [] 

for n in range(1, 1000, 100):
    url = gen_search_url("shop", "딥러닝", n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
    
result_mol = pd.concat(result_mol)
# Out:
# [2024-03-13 20:21:37.148302] Url Request Success
# [2024-03-13 20:21:37.462886] Url Request Success
# [2024-03-13 20:21:37.877204] Url Request Success
# [2024-03-13 20:21:38.255437] Url Request Success
# [2024-03-13 20:21:38.667734] Url Request Success
# [2024-03-13 20:21:38.986436] Url Request Success
# [2024-03-13 20:21:39.378608] Url Request Success
# [2024-03-13 20:21:39.792645] Url Request Success
# [2024-03-13 20:21:40.198368] Url Request Success
# [2024-03-13 20:21:40.548353] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
result_mol.reset_index(drop=True, inplace=True)
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol
# Out:
#                                           title    lprice  \
# 0                  HP Z4G4 W-2223 워크스테이션 딥러닝 서버   2424580
# 1         딥러닝 AI 2GPU 워크스테이션 W5-3435X/RTX A6000  23485000
# 2       [2GPU] 딥러닝 서버 NF5280M6 G5315Y RTX A6000  22560000
# 3                        인공 지능 소형 서버 딥 러닝 AI 지원   3064460
# 4           HP 에이치피 ai딥러닝 전문가 정보처리용 WORKSTATION   2424580
# ..                                          ...       ...
# 995                   수냉식 케이스 고급 커스텀 딥러닝 투명 게이밍    520500
# 996  Waveshare Jetson TX2 NX 개발 키트 딥 러닝  에지 컴퓨팅    738290
# 997      Sipeed M1n riscv AI + loT 딥 러닝 골드핑거 모듈     35840
# 998     NVIDIA Tesla P40 용 오리지널 컴퓨팅 그래픽 카드 딥 러닝    262130
# 999            Synology 딥 러닝 NVR DVA1622 2 개 베이   1561310
#
#                                                   link   mall
# 0    https://search.shopping.naver.com/gate.nhn?id=...   11번가
# 1    https://search.shopping.naver.com/gate.nhn?id=...    G마켓
# 2    https://search.shopping.naver.com/gate.nhn?id=...   11번가
# ...

# %%
# 가격을 float형으로 변환
result_mol["lprice"] = result_mol["lprice"].astype("float")
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## 5. to_excel() -> export to excel
# 이제 데이터를 엑셀로 저장

# %%
# !pip install xlsxwriter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    --------------------------------------- 159.9/159.9 kB 10.0 MB/s eta 0:00:00
# ...

# %%
writer = pd.ExcelWriter("deep_learning_in_naver_shop.xlsx", engine="xlsxwriter")
result_mol.to_excel(writer, sheet_name="Sheet1")

workbook = writer.book 
worksheet = writer.sheets["Sheet1"]
worksheet.set_column("A:A", 4)
worksheet.set_column("B:B", 60)
worksheet.set_column("C:C", 10)
worksheet.set_column("D:D", 10)
worksheet.set_column("E:E", 50)
worksheet.set_column("F:F", 10)

worksheet.conditional_format("C2:C1001", {"type": "3_color_scale"})
writer.close() # 영상강의에서 save()에서 close()로 바뀜

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    --------------------------------------- 250.0/250.0 kB 16.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel('deep_learning_in_naver_shop.xlsx')
df
# Out:
#      Unnamed: 0                                       title    lprice  \
# 0             0                HP Z4G4 W-2223 워크스테이션 딥러닝 서버   2424580
# 1             1       딥러닝 AI 2GPU 워크스테이션 W5-3435X/RTX A6000  23485000
# 2             2     [2GPU] 딥러닝 서버 NF5280M6 G5315Y RTX A6000  22560000
# 3             3                      인공 지능 소형 서버 딥 러닝 AI 지원   3064460
# 4             4         HP 에이치피 ai딥러닝 전문가 정보처리용 WORKSTATION   2424580
# ..          ...                                         ...       ...
# 995         995                   수냉식 케이스 고급 커스텀 딥러닝 투명 게이밍    520500
# 996         996  Waveshare Jetson TX2 NX 개발 키트 딥 러닝  에지 컴퓨팅    738290
# 997         997      Sipeed M1n riscv AI + loT 딥 러닝 골드핑거 모듈     35840
# 998         998     NVIDIA Tesla P40 용 오리지널 컴퓨팅 그래픽 카드 딥 러닝    262130
# 999         999            Synology 딥 러닝 NVR DVA1622 2 개 베이   1561310
#
#                                                   link   mall
# 0    https://search.shopping.naver.com/gate.nhn?id=...   11번가
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                           title    lprice  \
# 0                  HP Z4G4 W-2223 워크스테이션 딥러닝 서버   2424580
# 1         딥러닝 AI 2GPU 워크스테이션 W5-3435X/RTX A6000  23485000
# 2       [2GPU] 딥러닝 서버 NF5280M6 G5315Y RTX A6000  22560000
# 3                        인공 지능 소형 서버 딥 러닝 AI 지원   3064460
# 4           HP 에이치피 ai딥러닝 전문가 정보처리용 WORKSTATION   2424580
# ..                                          ...       ...
# 995                   수냉식 케이스 고급 커스텀 딥러닝 투명 게이밍    520500
# 996  Waveshare Jetson TX2 NX 개발 키트 딥 러닝  에지 컴퓨팅    738290
# 997      Sipeed M1n riscv AI + loT 딥 러닝 골드핑거 모듈     35840
# 998     NVIDIA Tesla P40 용 오리지널 컴퓨팅 그래픽 카드 딥 러닝    262130
# 999            Synology 딥 러닝 NVR DVA1622 2 개 베이   1561310
#
#                                                   link   mall
# 0    https://search.shopping.naver.com/gate.nhn?id=...   11번가
# 1    https://search.shopping.naver.com/gate.nhn?id=...    G마켓
# 2    https://search.shopping.naver.com/gate.nhn?id=...   11번가
# ...

# %% [markdown]
# ## 시각화

# %%
import seaborn as sns

plt.figure(figsize=(15, 6))
sns.countplot(
    x="mall", 
    data=result_mol, 
    palette="RdYlGn",
    order=df["mall"].value_counts().index
)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\emddj\AppData\Local\Temp\ipykernel_3164\2472927185.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
