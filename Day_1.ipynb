# %% [markdown]
# <a href="https://colab.research.google.com/github/kimhwidam/zerobase_EDA/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zerobase EDA 1일차
# ## 서울시 CCTV 현황 분석

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title('데이터 사이언스')
# Out:
# Text(0.5, 1.0, '데이터 사이언스')
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50616 (\N{HANGUL SYLLABLE EON}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# ## 한글 깨짐 방지 패키지 설치

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 49.6 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
plt.title('데이터 사이언스')
# Out:
# Text(0.5, 1.0, '데이터 사이언스')

# %% [markdown]
# ## 데이터 출처 - 서울 열린 데이터 광장
# 서울광역시 구별 CCTV 현황 데이터 - https://data.seoul.go.kr/dataList/OA-2734/F/1/datasetView.do
#
# 서울광역시 구별 인구 현황 데이터 - https://data.seoul.go.kr/dataList/11067/S/2/datasetView.do

# %% [markdown]
# ## 데이터 읽기

# %%
import pandas as pd

# csv 파일과 excel 파일 읽어오기
cctv_data = pd.read_csv('/content/01. Seoul_CCTV.csv')
# excel 파일 윗부분 2번째 행부터 가져오고, B, D, G, J, N 컬럼만 가져오기
pop_data = pd.read_excel('/content/01. Seoul_Population.xls', header=2,
                         usecols='B, D, G, J, N')

# %%
# CCTV 데이터
cctv_data
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573     78     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009     78    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# ...

# %%
# 인구수 데이터
pop_data
# Out:
#      자치구         계      계.1     계.2  65세이상고령자
# 0     합계  10124579  9857426  267153   1365126
# 1    종로구    164257   154770    9487     26182
# 2     중구    134593   125709    8884     21384
# 3    용산구    244444   229161   15283     36882
# 4    성동구    312711   304808    7903     41273
# 5    광진구    372298   357703   14595     43953
# 6   동대문구    366011   350647   15364     55718
# 7    중랑구    412780   408226    4554     59262
# 8    성북구    455407   444055   11352     66251
# 9    강북구    328002   324479    3523     56530
# 10   도봉구    346234   344166    2068     53488
# 11   노원구    558075   554403    3672     74243
# 12   은평구    491202   486794    4408     74559
# 13  서대문구    325028   312800   12228     49266
# 14   마포구    385783   374915   10868     49615
# 15   양천구    475018   471154    3864     55234
# 16   강서구    608255   601691    6564     76032
# 17   구로구    441559   410742   30817     58794
# 18   금천구    253491   235154   18337     34170
# ...

# %%
# 처음 줄 부터 5줄까지만 보여주기
cctv_data.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
pop_data.head()
# Out:
#    자치구         계      계.1     계.2  65세이상고령자
# 0   합계  10124579  9857426  267153   1365126
# 1  종로구    164257   154770    9487     26182
# 2   중구    134593   125709    8884     21384
# 3  용산구    244444   229161   15283     36882
# 4  성동구    312711   304808    7903     41273

# %%
# 끝에서부터 5개의 데이터 불러오기
cctv_data.tail()
# Out:
#     기관명    소계  2013년도 이전  2014년  2015년  2016년
# 20  용산구  2096       1368    218    112    398
# 21  은평구  2108       1138    224    278    468
# 22  종로구  1619        464    314    211    630
# 23   중구  1023        413    190     72    348
# 24  중랑구   916        509    121    177    109

# %% [markdown]
# ## 데이터 프레임 다루기

# %%
# 데이터프레임 index 확인
cctv_data.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
# 컬럼명들만 불러오기
cctv_data.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
# 데이터프레임 value 확인
cctv_data.values
# Out:
# array([['강남구', 3238, 1292, 430, 584, 932],
#        ['강동구', 1010, 379, 99, 155, 377],
#        ['강북구', 831, 369, 120, 138, 204],
#        ['강서구', 911, 388, 258, 184, 81],
#        ['관악구', 2109, 846, 260, 390, 613],
#        ['광진구', 878, 573, 78, 53, 174],
#        ['구로구', 1884, 1142, 173, 246, 323],
#        ['금천구', 1348, 674, 51, 269, 354],
#        ['노원구', 1566, 542, 57, 451, 516],
#        ['도봉구', 825, 238, 159, 42, 386],
#        ['동대문구', 1870, 1070, 23, 198, 579],
#        ['동작구', 1302, 544, 341, 103, 314],
#        ['마포구', 980, 314, 118, 169, 379],
#        ['서대문구', 1254, 844, 50, 68, 292],
#        ['서초구', 2297, 1406, 157, 336, 398],
#        ['성동구', 1327, 730, 91, 241, 265],
#        ['성북구', 1651, 1009, 78, 360, 204],
#        ['송파구', 1081, 529, 21, 68, 463],
#        ['양천구', 2482, 1843, 142, 30, 467],
#        ['영등포구', 1277, 495, 214, 195, 373],
#        ['용산구', 2096, 1368, 218, 112, 398],
#        ['은평구', 2108, 1138, 224, 278, 468],
# ...

# %%
# 데이터프레임의 기본 정보 확인(컬럼 크기, 데이터 형, 결측치)
# object는 데이터프레임의 string형
cctv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구별         25 non-null     object
#  1   소계         25 non-null     int64
#  2   2013년도 이전  25 non-null     int64
#  3   2014년      25 non-null     int64
#  4   2015년      25 non-null     int64
#  5   2016년      25 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
# 데이터프레임의 통계적 기본 정보를 확인
cctv_data.describe()
# Out:
#                 소계    2013년도 이전       2014년       2015년       2016년
# count    25.000000    25.000000   25.000000   25.000000   25.000000
# mean   1515.320000   764.760000  159.480000  205.200000  385.880000
# std     616.774656   415.510257  104.132976  137.877059  182.479981
# min     825.000000   238.000000   21.000000   30.000000   81.000000
# 25%    1010.000000   464.000000   78.000000  103.000000  292.000000
# 50%    1327.000000   573.000000  142.000000  184.000000  377.000000
# 75%    1884.000000  1070.000000  218.000000  269.000000  467.000000
# max    3238.000000  1843.000000  430.000000  584.000000  932.000000

# %%
# 데이터 정렬(ex. 소계 컬럼을 기준으로 내림차순)
cctv_data.sort_values(by='소계', ascending=False)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 18   양천구  2482       1843    142     30    467
# 14   서초구  2297       1406    157    336    398
# 4    관악구  2109        846    260    390    613
# 21   은평구  2108       1138    224    278    468
# 20   용산구  2096       1368    218    112    398
# 6    구로구  1884       1142    173    246    323
# 10  동대문구  1870       1070     23    198    579
# 16   성북구  1651       1009     78    360    204
# 22   종로구  1619        464    314    211    630
# 8    노원구  1566        542     57    451    516
# 7    금천구  1348        674     51    269    354
# 15   성동구  1327        730     91    241    265
# 11   동작구  1302        544    341    103    314
# 19  영등포구  1277        495    214    195    373
# 13  서대문구  1254        844     50     68    292
# 17   송파구  1081        529     21     68    463
# 23    중구  1023        413    190     72    348
# 1    강동구  1010        379     99    155    377
# ...

# %% [markdown]
# ## 데이터 슬라이싱

# %%
# 특정 컬럼만 읽기
cctv_data['구별']
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 구별, dtype: object

# %%
# [n:m] -> n부터 m-1까지 행을 읽어라
cctv_data[0:5]
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
# Pandas의 보편적인 슬라이싱(첫번째: 행, 두번째: 컬럼)
cctv_data.loc[:, ['구별', '소계']]
# Out:
#       구별    소계
# 0    강남구  3238
# 1    강동구  1010
# 2    강북구   831
# 3    강서구   911
# 4    관악구  2109
# 5    광진구   878
# 6    구로구  1884
# 7    금천구  1348
# 8    노원구  1566
# 9    도봉구   825
# 10  동대문구  1870
# 11   동작구  1302
# 12   마포구   980
# 13  서대문구  1254
# 14   서초구  2297
# 15   성동구  1327
# 16   성북구  1651
# 17   송파구  1081
# 18   양천구  2482
# 19  영등포구  1277
# 20   용산구  2096
# 21   은평구  2108
# 22   종로구  1619
# 23    중구  1023
# 24   중랑구   916

# %%
# 행, 열을 번호로 슬라이싱
cctv_data.iloc[3:5, 0:2]
# Out:
#     구별    소계
# 3  강서구   911
# 4  관악구  2109

# %%
# 조건을 넣어서 슬라이싱(ex. 소계 컬럼의 값들 중 1000보다 큰 행만 가져와라)
cctv_data[cctv_data['소계'] > 1000]
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 4    관악구  2109        846    260    390    613
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009     78    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348

# %%
# 특정 요소가 있는지 확인(ex. 구별 컬럼에 강북구와 성북구가 있나?)
cctv_data['구별'].isin(['강북구', '성북구'])
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: 구별, dtype: bool

# %%
# 특정 컬럼 제거(ex. 구별 컬럼을 제거해라)
# del cctv_data['구별']
# cctv_data
# Out:
#       소계  2013년도 이전  2014년  2015년  2016년
# 0   3238       1292    430    584    932
# 1   1010        379     99    155    377
# 2    831        369    120    138    204
# 3    911        388    258    184     81
# 4   2109        846    260    390    613
# 5    878        573     78     53    174
# 6   1884       1142    173    246    323
# 7   1348        674     51    269    354
# 8   1566        542     57    451    516
# 9    825        238    159     42    386
# 10  1870       1070     23    198    579
# 11  1302        544    341    103    314
# 12   980        314    118    169    379
# 13  1254        844     50     68    292
# 14  2297       1406    157    336    398
# 15  1327        730     91    241    265
# 16  1651       1009     78    360    204
# 17  1081        529     21     68    463
# 18  2482       1843    142     30    467
# 19  1277        495    214    195    373
# 20  2096       1368    218    112    398
# 21  2108       1138    224    278    468
# ...

# %%
# 각 컬럼 누적합
# apply함수로 특정 컬럼의 통계적 정보 등 수학적 정보 추출 가능
import numpy as np

cctv_data.apply(np.cumsum)
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년
# 0    3238       1292    430    584    932
# 1    4248       1671    529    739   1309
# 2    5079       2040    649    877   1513
# 3    5990       2428    907   1061   1594
# 4    8099       3274   1167   1451   2207
# 5    8977       3847   1245   1504   2381
# 6   10861       4989   1418   1750   2704
# 7   12209       5663   1469   2019   3058
# 8   13775       6205   1526   2470   3574
# 9   14600       6443   1685   2512   3960
# 10  16470       7513   1708   2710   4539
# 11  17772       8057   2049   2813   4853
# 12  18752       8371   2167   2982   5232
# 13  20006       9215   2217   3050   5524
# 14  22303      10621   2374   3386   5922
# 15  23630      11351   2465   3627   6187
# 16  25281      12360   2543   3987   6391
# 17  26362      12889   2564   4055   6854
# 18  28844      14732   2706   4085   7321
# 19  30121      15227   2920   4280   7694
# 20  32217      16595   3138   4392   8092
# ...

# %% [markdown]
# ## 데이터 전처리

# %%
# 컬럼명 바꾸기(inplace를 True로 하면 바로 보여짐)
cctv_data.rename(columns={cctv_data.columns[0]: '구별'}, inplace=True)
cctv_data.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
# 인구수 데이터 컬럼명 바꾸기
pop_data.rename(columns={pop_data.columns[0]: '구별',
                         pop_data.columns[1]: '인구수',
                         pop_data.columns[2]: '한국인',
                         pop_data.columns[3]: '외국인',
                         pop_data.columns[4]: '고령자'}, inplace=True)
pop_data.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10124579  9857426  267153  1365126
# 1  종로구    164257   154770    9487    26182
# 2   중구    134593   125709    8884    21384
# 3  용산구    244444   229161   15283    36882
# 4  성동구    312711   304808    7903    41273

# %%
# CCTV 개수가 가장 많은 구는 강남구, 가장 적은 구는 도봉구
cctv_data.sort_values(by='소계', ascending=False)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 18   양천구  2482       1843    142     30    467
# 14   서초구  2297       1406    157    336    398
# 4    관악구  2109        846    260    390    613
# 21   은평구  2108       1138    224    278    468
# 20   용산구  2096       1368    218    112    398
# 6    구로구  1884       1142    173    246    323
# 10  동대문구  1870       1070     23    198    579
# 16   성북구  1651       1009     78    360    204
# 22   종로구  1619        464    314    211    630
# 8    노원구  1566        542     57    451    516
# 7    금천구  1348        674     51    269    354
# 15   성동구  1327        730     91    241    265
# 11   동작구  1302        544    341    103    314
# 19  영등포구  1277        495    214    195    373
# 13  서대문구  1254        844     50     68    292
# 17   송파구  1081        529     21     68    463
# 23    중구  1023        413    190     72    348
# 1    강동구  1010        379     99    155    377
# ...

# %%
# 3년간 그 전 보유한 갯수 대비 CCTV를 많이 설치한 구의 비율 컬럼 추가해서 확인
cctv_data['최근증가율'] = ((cctv_data['2014년'] +
                      cctv_data['2015년'] +
                      cctv_data['2016년']) / cctv_data['2013년도 이전'] * 100)

cctv_data.sort_values(by='최근증가율', ascending=False)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22   종로구  1619        464    314    211    630  248.922414
# 9    도봉구   825        238    159     42    386  246.638655
# 12   마포구   980        314    118    169    379  212.101911
# 8    노원구  1566        542     57    451    516  188.929889
# 1    강동구  1010        379     99    155    377  166.490765
# 19  영등포구  1277        495    214    195    373  157.979798
# 0    강남구  3238       1292    430    584    932  150.619195
# 4    관악구  2109        846    260    390    613  149.290780
# 23    중구  1023        413    190     72    348  147.699758
# 11   동작구  1302        544    341    103    314  139.338235
# 3    강서구   911        388    258    184     81  134.793814
# 2    강북구   831        369    120    138    204  125.203252
# 17   송파구  1081        529     21     68    463  104.347826
# 7    금천구  1348        674     51    269    354  100.000000
# 21   은평구  2108       1138    224    278    468   85.237258
# ...

# %% [markdown]
# ### 단순히 구별 CCTV 개수로 한계...
# -> 인구현황과 함께 비교해야함

# %%
pop_data
# Out:
#       구별       인구수      한국인     외국인      고령자
# 0     합계  10124579  9857426  267153  1365126
# 1    종로구    164257   154770    9487    26182
# 2     중구    134593   125709    8884    21384
# 3    용산구    244444   229161   15283    36882
# 4    성동구    312711   304808    7903    41273
# 5    광진구    372298   357703   14595    43953
# 6   동대문구    366011   350647   15364    55718
# 7    중랑구    412780   408226    4554    59262
# 8    성북구    455407   444055   11352    66251
# 9    강북구    328002   324479    3523    56530
# 10   도봉구    346234   344166    2068    53488
# 11   노원구    558075   554403    3672    74243
# 12   은평구    491202   486794    4408    74559
# 13  서대문구    325028   312800   12228    49266
# 14   마포구    385783   374915   10868    49615
# 15   양천구    475018   471154    3864    55234
# 16   강서구    608255   601691    6564    76032
# 17   구로구    441559   410742   30817    58794
# 18   금천구    253491   235154   18337    34170
# 19  영등포구    402024   368550   33474    53981
# ...

# %% [markdown]
# ### 첫 행(합계) 데이터는 필요 없음
# -> drop으로 행 지우기

# %%
pop_data.drop([0], inplace=True)
pop_data.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  164257  154770   9487  26182
# 2   중구  134593  125709   8884  21384
# 3  용산구  244444  229161  15283  36882
# 4  성동구  312711  304808   7903  41273
# 5  광진구  372298  357703  14595  43953

# %%
# unique() -> 특정 컬럼에 대한 데이터의 중복을 제거한 값만 표시
pop_data['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
# 구별의 unique한 값은 25
len(pop_data['구별'].unique())
# Out:
# 25

# %%
# 가장 인구가 많은 구는 송파구, 가장 적은 구는 중구
pop_data.sort_values(by='인구수', ascending=False)
# Out:
#       구별     인구수     한국인    외국인    고령자
# 24   송파구  671173  664496   6677  76582
# 16   강서구  608255  601691   6564  76032
# 23   강남구  561052  556164   4888  65060
# 11   노원구  558075  554403   3672  74243
# 21   관악구  520929  503297  17632  70046
# 12   은평구  491202  486794   4408  74559
# 15   양천구  475018  471154   3864  55234
# 8    성북구  455407  444055  11352  66251
# 22   서초구  445401  441102   4299  53205
# 17   구로구  441559  410742  30817  58794
# 25   강동구  440359  436223   4136  56161
# 7    중랑구  412780  408226   4554  59262
# 20   동작구  408493  396217  12276  57255
# 19  영등포구  402024  368550  33474  53981
# 14   마포구  385783  374915  10868  49615
# 5    광진구  372298  357703  14595  43953
# 6   동대문구  366011  350647  15364  55718
# 10   도봉구  346234  344166   2068  53488
# 9    강북구  328002  324479   3523  56530
# 13  서대문구  325028  312800  12228  49266
# 4    성동구  312711  304808   7903  41273
# 18   금천구  253491  235154  18337  34170
# 3    용산구  244444  229161  15283  36882
# ...

# %%
# 외국인과 고령자 비율을 알아보자
pop_data['외국인비율'] = pop_data['외국인'] / pop_data['인구수'] * 100
pop_data['고령자비율'] = pop_data['고령자'] / pop_data['인구수'] * 100

pop_data
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1    종로구  164257  154770   9487  26182  5.775705  15.939656
# 2     중구  134593  125709   8884  21384  6.600640  15.887899
# 3    용산구  244444  229161  15283  36882  6.252148  15.088118
# 4    성동구  312711  304808   7903  41273  2.527254  13.198448
# 5    광진구  372298  357703  14595  43953  3.920247  11.805865
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040
# 7    중랑구  412780  408226   4554  59262  1.103251  14.356800
# 8    성북구  455407  444055  11352  66251  2.492715  14.547646
# 9    강북구  328002  324479   3523  56530  1.074079  17.234651
# 10   도봉구  346234  344166   2068  53488  0.597284  15.448512
# 11   노원구  558075  554403   3672  74243  0.657976  13.303409
# 12   은평구  491202  486794   4408  74559  0.897390  15.178888
# 13  서대문구  325028  312800  12228  49266  3.762137  15.157463
# 14   마포구  385783  374915  10868  49615  2.817128  12.860857
# 15   양천구  475018  471154   3864  55234  0.813443  11.627770
# ...

# %%
# 외국인이 가장 많은 구는 영등포구, 가장 적은 구는 도봉구
pop_data.sort_values(by='외국인', ascending=False)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  402024  368550  33474  53981  8.326369  13.427308
# 17   구로구  441559  410742  30817  58794  6.979135  13.315095
# 18   금천구  253491  235154  18337  34170  7.233787  13.479769
# 21   관악구  520929  503297  17632  70046  3.384722  13.446362
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040
# 3    용산구  244444  229161  15283  36882  6.252148  15.088118
# 5    광진구  372298  357703  14595  43953  3.920247  11.805865
# 20   동작구  408493  396217  12276  57255  3.005192  14.016152
# 13  서대문구  325028  312800  12228  49266  3.762137  15.157463
# 8    성북구  455407  444055  11352  66251  2.492715  14.547646
# 14   마포구  385783  374915  10868  49615  2.817128  12.860857
# 1    종로구  164257  154770   9487  26182  5.775705  15.939656
# 2     중구  134593  125709   8884  21384  6.600640  15.887899
# 4    성동구  312711  304808   7903  41273  2.527254  13.198448
# 24   송파구  671173  664496   6677  76582  0.994825  11.410173
# ...

# %%
# 외국인 비율이 가장 높은 구는 영등포구, 가장 적은 구는 도봉구
pop_data.sort_values(by='외국인비율', ascending=False)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  402024  368550  33474  53981  8.326369  13.427308
# 18   금천구  253491  235154  18337  34170  7.233787  13.479769
# 17   구로구  441559  410742  30817  58794  6.979135  13.315095
# 2     중구  134593  125709   8884  21384  6.600640  15.887899
# 3    용산구  244444  229161  15283  36882  6.252148  15.088118
# 1    종로구  164257  154770   9487  26182  5.775705  15.939656
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040
# 5    광진구  372298  357703  14595  43953  3.920247  11.805865
# 13  서대문구  325028  312800  12228  49266  3.762137  15.157463
# 21   관악구  520929  503297  17632  70046  3.384722  13.446362
# 20   동작구  408493  396217  12276  57255  3.005192  14.016152
# 14   마포구  385783  374915  10868  49615  2.817128  12.860857
# 4    성동구  312711  304808   7903  41273  2.527254  13.198448
# 8    성북구  455407  444055  11352  66251  2.492715  14.547646
# 7    중랑구  412780  408226   4554  59262  1.103251  14.356800
# ...

# %%
# 고령자가 가장 많은 구는 송파구, 가장 적은 구는 중구
pop_data.sort_values(by='고령자', ascending=False)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24   송파구  671173  664496   6677  76582  0.994825  11.410173
# 16   강서구  608255  601691   6564  76032  1.079153  12.500021
# 12   은평구  491202  486794   4408  74559  0.897390  15.178888
# 11   노원구  558075  554403   3672  74243  0.657976  13.303409
# 21   관악구  520929  503297  17632  70046  3.384722  13.446362
# 8    성북구  455407  444055  11352  66251  2.492715  14.547646
# 23   강남구  561052  556164   4888  65060  0.871220  11.596073
# 7    중랑구  412780  408226   4554  59262  1.103251  14.356800
# 17   구로구  441559  410742  30817  58794  6.979135  13.315095
# 20   동작구  408493  396217  12276  57255  3.005192  14.016152
# 9    강북구  328002  324479   3523  56530  1.074079  17.234651
# 25   강동구  440359  436223   4136  56161  0.939234  12.753458
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040
# 15   양천구  475018  471154   3864  55234  0.813443  11.627770
# 19  영등포구  402024  368550  33474  53981  8.326369  13.427308
# ...

# %%
# 고령자비율이 가장 많은 구는 강북구, 가장 적은 구는 송파구
pop_data.sort_values(by='고령자비율', ascending=False)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9    강북구  328002  324479   3523  56530  1.074079  17.234651
# 1    종로구  164257  154770   9487  26182  5.775705  15.939656
# 2     중구  134593  125709   8884  21384  6.600640  15.887899
# 10   도봉구  346234  344166   2068  53488  0.597284  15.448512
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040
# 12   은평구  491202  486794   4408  74559  0.897390  15.178888
# 13  서대문구  325028  312800  12228  49266  3.762137  15.157463
# 3    용산구  244444  229161  15283  36882  6.252148  15.088118
# 8    성북구  455407  444055  11352  66251  2.492715  14.547646
# 7    중랑구  412780  408226   4554  59262  1.103251  14.356800
# 20   동작구  408493  396217  12276  57255  3.005192  14.016152
# 18   금천구  253491  235154  18337  34170  7.233787  13.479769
# 21   관악구  520929  503297  17632  70046  3.384722  13.446362
# 19  영등포구  402024  368550  33474  53981  8.326369  13.427308
# 17   구로구  441559  410742  30817  58794  6.979135  13.315095
# ...

# %% [markdown]
# ### CCTV 데이터와 인구현황 데이터로 얻을게 별로 없음...
# -> 두 데이터를 같이 비교하고 관계도 조사하기 위해 합쳐야함

# %% [markdown]
# ## 두 데이터 합치기
# -> merge를 이용해서 데이터 병합
# * pd.merge(data1, data2, on='key') -> key 컬럼을 기준으로 병합
# * pd.merge(data1, data2, how='data1', on='key') -> data1에 key 컬럼을 기준으로 data2 병합
# *  pd.merge(data1, data2, how='outer', on='key') -> 둘 다 손상되지 않도록 key 컬럼 기준으로 병합
# * pd.merge(data1, data2, how='inner', on='key') -> key 컬럼에서 두 데이터에 공통분모만 병합
#
# #### how='inner'는 default값

# %%
total_data = pd.merge(cctv_data, pop_data, on='구별')
total_data.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율     인구수     한국인  \
# 0  강남구  3238       1292    430    584    932  150.619195  561052  556164
# 1  강동구  1010        379     99    155    377  166.490765  440359  436223
# 2  강북구   831        369    120    138    204  125.203252  328002  324479
# 3  강서구   911        388    258    184     81  134.793814  608255  601691
# 4  관악구  2109        846    260    390    613  149.290780  520929  503297
#
#      외국인    고령자     외국인비율      고령자비율
# 0   4888  65060  0.871220  11.596073
# 1   4136  56161  0.939234  12.753458
# 2   3523  56530  1.074079  17.234651
# 3   6564  76032  1.079153  12.500021
# 4  17632  70046  3.384722  13.446362

# %%
# 년도별 CCTV 개수 컬럼은 제거
del_columns = ['2013년도 이전', '2014년', '2015년', '2016년']
total_data = total_data.drop(del_columns, axis=1)
total_data.rename(columns={'소계': 'CCTV 소계'}, inplace=True)
total_data
# Out:
#       구별  CCTV 소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 0    강남구     3238  150.619195  561052  556164   4888  65060  0.871220
# 1    강동구     1010  166.490765  440359  436223   4136  56161  0.939234
# 2    강북구      831  125.203252  328002  324479   3523  56530  1.074079
# 3    강서구      911  134.793814  608255  601691   6564  76032  1.079153
# 4    관악구     2109  149.290780  520929  503297  17632  70046  3.384722
# 5    광진구      878   53.228621  372298  357703  14595  43953  3.920247
# 6    구로구     1884   64.973730  441559  410742  30817  58794  6.979135
# 7    금천구     1348  100.000000  253491  235154  18337  34170  7.233787
# 8    노원구     1566  188.929889  558075  554403   3672  74243  0.657976
# 9    도봉구      825  246.638655  346234  344166   2068  53488  0.597284
# 10  동대문구     1870   74.766355  366011  350647  15364  55718  4.197688
# 11   동작구     1302  139.338235  408493  396217  12276  57255  3.005192
# ...

# %%
# 데이터프레임 index를 구별로 재지정
total_data.set_index('구별', inplace=True)
total_data.head()
# Out:
#      CCTV 소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구     3238  150.619195  561052  556164   4888  65060  0.871220  11.596073
# 강동구     1010  166.490765  440359  436223   4136  56161  0.939234  12.753458
# 강북구      831  125.203252  328002  324479   3523  56530  1.074079  17.234651
# 강서구      911  134.793814  608255  601691   6564  76032  1.079153  12.500021
# 관악구     2109  149.290780  520929  503297  17632  70046  3.384722  13.446362

# %% [markdown]
# ### 우리의 목표는 인구대비 상대적으로 CCTV가 적은 구를 찾는 것
# -> 인구데이터와 CCTV는 상관관계 확인 필요

# %%
# 상관관계 확인 -> corr() 함수
# 상관관계를 조사해서 0.2 이상의 최소한의 근거가 있는 데이터 비교
# CCTV 전체 수와 가장 상관관계가 있는 데이터는 인구수 데이터
total_data.corr()
# Out:
#           CCTV 소계     최근증가율       인구수       한국인       외국인       고령자     외국인비율  \
# CCTV 소계  1.000000 -0.264378  0.232555  0.227852  0.030421  0.163905 -0.045956
# 최근증가율   -0.264378  1.000000 -0.097165 -0.086341 -0.156421 -0.072251 -0.047102
# 인구수      0.232555 -0.097165  1.000000  0.998151 -0.167243  0.936737 -0.601076
# 한국인      0.227852 -0.086341  0.998151  1.000000 -0.226853  0.936155 -0.645463
# 외국인      0.030421 -0.156421 -0.167243 -0.226853  1.000000 -0.175318  0.838612
# 고령자      0.163905 -0.072251  0.936737  0.936155 -0.175318  1.000000 -0.620300
# 외국인비율   -0.045956 -0.047102 -0.601076 -0.645463  0.838612 -0.620300  1.000000
# 고령자비율   -0.267841  0.190396 -0.637414 -0.628360 -0.021147 -0.348840  0.242816
#
#             고령자비율
# CCTV 소계 -0.267841
# 최근증가율    0.190396
# 인구수     -0.637414
# 한국인     -0.628360
# 외국인     -0.021147
# 고령자     -0.348840
# 외국인비율    0.242816
# 고령자비율    1.000000

# %% [markdown]
# ### 그러므로 우리는 구별 인구대비 CCTV 현황을 분석해서 상대적으로 CCTV가 적거나 많은 구를 찾아야 함

# %%
# CCTV 비율이 가장 높은 구는 종로구, 가장 적은 구는 강서구
total_data['cctv비율'] = (total_data['CCTV 소계'] / total_data['인구수']) * 100
total_data.sort_values(by='cctv비율', ascending=False)
# Out:
#       CCTV 소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 종로구      1619  248.922414  164257  154770   9487  26182  5.775705  15.939656
# 용산구      2096   53.216374  244444  229161  15283  36882  6.252148  15.088118
# 중구       1023  147.699758  134593  125709   8884  21384  6.600640  15.887899
# 강남구      3238  150.619195  561052  556164   4888  65060  0.871220  11.596073
# 금천구      1348  100.000000  253491  235154  18337  34170  7.233787  13.479769
# 양천구      2482   34.671731  475018  471154   3864  55234  0.813443  11.627770
# 서초구      2297   63.371266  445401  441102   4299  53205  0.965198  11.945415
# 동대문구     1870   74.766355  366011  350647  15364  55718  4.197688  15.223040
# 은평구      2108   85.237258  491202  486794   4408  74559  0.897390  15.178888
# 구로구      1884   64.973730  441559  410742  30817  58794  6.979135  13.315095
# 성동구      1327   81.780822  312711  304808   7903  41273  2.527254  13.198448
# ...

# %% [markdown]
# ## 데이터 시각화

# %%
total_data.head()
# Out:
#      CCTV 소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 강남구     3238  150.619195  561052  556164   4888  65060  0.871220  11.596073
# 강동구     1010  166.490765  440359  436223   4136  56161  0.939234  12.753458
# 강북구      831  125.203252  328002  324479   3523  56530  1.074079  17.234651
# 강서구      911  134.793814  608255  601691   6564  76032  1.079153  12.500021
# 관악구     2109  149.290780  520929  503297  17632  70046  3.384722  13.446362
#
#        cctv비율
# 구별
# 강남구  0.577130
# 강동구  0.229358
# 강북구  0.253352
# 강서구  0.149773
# 관악구  0.404854

# %%
# 바로 plot()을 써서 시각화 가능(세로 bar차트, figsize는 나타나지는 그래프 전체 크기)
total_data['인구수'].plot(title='구별 인구수', kind='bar', figsize=(10,10))
# Out:
# <Axes: title={'center': '구별 인구수'}, xlabel='구별'>

# %%
# barh는 가로 bar차트
total_data['인구수'].plot(title='구별 인구수', kind='barh', figsize=(10,10))
# Out:
# <Axes: title={'center': '구별 인구수'}, ylabel='구별'>

# %%
# CCTV 개수를 정렬한 다음 시각화
# grid는 구간별 선 표시, title은 그래프 제목 표시
# CCTV가 가장 많은 구는 강남구, 가장 적은 구는 도봉구
total_data['CCTV 소계'].sort_values().plot(title='구별 CCTV수', grid=True, kind='barh', figsize=(10,10))
# Out:
# <Axes: title={'center': '구별 CCTV수'}, ylabel='구별'>

# %%
# CCTV 비율이 가장 높은 구는 종로구, 가장 낮은 구는 강서구
total_data['cctv비율'].sort_values().plot(title='구별 CCTV 비율', grid=True, kind='barh', figsize=(10,10))
# Out:
# <Axes: title={'center': '구별 CCTV 비율'}, ylabel='구별'>

# %% [markdown]
# ### 그럼 이제 경향을 파악할 필요가 있음
# * 단순 CCTV 수와 비율로 데이터를 보아도 전체 경향과 함께 보지 않으면 데이터를 제대로 이해하기 어려움...

# %%
# sctter 그래프로 먼저 시각화
plt.figure(figsize=(14, 10))
plt.scatter(total_data['인구수'], total_data['CCTV 소계'],
            s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV 수')
plt.grid()
plt.show()

# %% [markdown]
# ### Numpy를 이용한 1차 직선 만들기
# * np.polyfit: 직선을 구성하기 위한 계수 계산
# * np.poly1d: polyfit으로 찾은 계수로 python에서 사용할 함수로 만들어 줌

# %%
import numpy as np

fp1 = np.polyfit(total_data['인구수'], total_data['CCTV 소계'], 1)
fp1
# Out:
# array([1.11155868e-03, 1.06515745e+03])

# %%
# 인구가 40만인 구에서 서울광역시의 전체 경향에 맞는 적당한 CCTV 개수는 1509.78
f1 = np.poly1d(fp1)
f1(400000)
# Out:
# 1509.7809252413333

# %%
# 경향선을 그리기 위해 X 데이터 생성
# np.linespace(a,b,n): a부터 b까지의 n개의 등간격 데이터 생성
# 그 후 경향 파악을 위해 시각화
fx = np.linspace(100000, 700000, 100)

plt.figure(figsize=(14, 10))
plt.scatter(total_data['인구수'], total_data['CCTV 소계'],
            s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV 수')
plt.grid()
plt.show()

# %% [markdown]
# ### 인구가 많을 수록 CCTV 수가 증가하는 경향이 대체로 보임
# -> 하지만 그래프 자체로는 아직 부족...
# * 그럼 경향과의 오차를 만들자

# %%
total_data['오차'] = total_data['CCTV 소계'] - f1(total_data['인구수'])

# 경향과 비교해서 데이터의 오차가 너무 나는 데이터 계산
data_sort_f = total_data.sort_values(by='오차', ascending=False)
data_sort_t = total_data.sort_values(by='오차', ascending=True)

# %%
data_sort_f.head()
# Out:
#      CCTV 소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 강남구     3238  150.619195  561052  556164   4888  65060  0.871220  11.596073
# 양천구     2482   34.671731  475018  471154   3864  55234  0.813443  11.627770
# 용산구     2096   53.216374  244444  229161  15283  36882  6.252148  15.088118
# 서초구     2297   63.371266  445401  441102   4299  53205  0.965198  11.945415
# 은평구     2108   85.237258  491202  486794   4408  74559  0.897390  15.178888
#
#        cctv비율           오차
# 구별
# 강남구  0.577130  1549.200326
# 양천구  0.522507   888.832166
# 용산구  0.857456   759.128697
# 서초구  0.515715   736.753199
# 은평구  0.429151   496.842700

# %%
data_sort_t.head()
# Out:
#      CCTV 소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 강서구      911  134.793814  608255  601691   6564  76032  1.079153  12.500021
# 송파구     1081  104.347826  671173  664496   6677  76582  0.994825  11.410173
# 도봉구      825  246.638655  346234  344166   2068  53488  0.597284  15.448512
# 중랑구      916   79.960707  412780  408226   4554  59262  1.103251  14.356800
# 광진구      878   53.228621  372298  357703  14595  43953  3.920247  11.805865
#
#        cctv비율          오차
# 구별
# 강서구  0.149773 -830.268578
# 송파구  0.161061 -730.205628
# 도봉구  0.238278 -625.016861
# 중랑구  0.221910 -607.986645
# 광진구  0.235833 -600.988527

# %%
from matplotlib.colors import ListedColormap

# color map을 임의로 사용자가 설정
color_step = ['red', 'blue', 'grey', 'blue', 'black', 'black']
my_cmap = ListedColormap(color_step)

plt.figure(figsize=(15, 10))
plt.scatter(total_data['인구수'], total_data['CCTV 소계'], c=total_data['오차'],
            s=50, cmap=my_cmap)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='grey')

# 오차가 너무 큰 범위에 구 이름을 써주는 과정
# 상위, 하위 5개만 표시
# 뒤에 1.02, 0.98을 곱해주는 이유는 점이랑 글씨가 겹치는 것을 방지하기 위해
for i in range(5):
    plt.text(
        data_sort_f['인구수'][i] * 1.05,
        data_sort_f['CCTV 소계'][i] * 1.01,
        data_sort_f.index[i],
        fontsize=15
    )

    plt.text(
        data_sort_t['인구수'][i] * 1.05,
        data_sort_t['CCTV 소계'][i] * 1.01,
        data_sort_t.index[i],
        fontsize=15
    )

plt.xlabel('인구수')
plt.ylabel('CCTV 수')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# ## 데이터 저장하기

# %%
total_data.to_csv('CCTV_result.csv', encoding='utf-8')
